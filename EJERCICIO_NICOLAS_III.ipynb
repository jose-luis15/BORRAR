# %% [markdown]
# <a href="https://colab.research.google.com/github/jose-luis15/BORRAR/blob/master/EJERCICIO_NICOLAS_III.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
######################################################################
#################### 1RA PARTE   ######################################
#######################################################################
import pandas as pd

print(f"---BIENVENIDO A LA CLINICA PERUANO JAPONES---\n -----------------------------------------")
print("\n Datos del Paciente")

data = list()
result = ["Nombres y Apellidos", "DNI", "edad", "categoria segun edad", "lugar de nacimiento", "domicilio", "celular",
          "tipo de sandre", "observación"]

data.append(input("Ingresar Nombre(s) y Apellidos: "))
data.append(input("Ingresar DNI: "))
edad = int(input("Ingresar Edad: "))
data.append(edad)

if edad >= 18:
    data.append("Es mayor de edad")
else:
    data.append("No es mayor de edad")

data.append(input("lugar donde nacio "))
data.append(input("Ingresar Domicilio: "))
data.append(int(input("Ingresar Celular: ")))
sangre = input("ingrese tipo de sangre ")
data.append(sangre)

if (sangre == "a"):
    data.append("su sangre es del tipo comun")
elif (sangre == "b"):
    data.append("su tipo de sangre no es tan comun")
elif (sangre == "ab"):
    data.append("su tipo de sangre no es tan comun")
elif (sangre == "ba"):
    data.append("su tipo de sangre no es tan comun")
else:
    data.append("No sabe que tipo de sangre tiene")

df01 = pd.DataFrame(list(zip(result, data)), columns=['REQUERIMIENTO', 'RECOPILADO'])

print("\nGracias por llenar datos del paciente ..!!!")

#######################################################################
#################### 2DA PARTE   ######################################
#######################################################################

data_asistencia = list()
print("\n--Contacto para Comunicarnos--\n")
data_asistencia.append(input("Ingresar Nombre(s) y Apellidos: "))
data_asistencia.append(int(input("Ingresar Celular: ")))
data_asistencia.append(input(
    "¿Padece de alguna de estas Enfermedades?\nEscriba la que corresponde: \n- Diabetes \n- Hipertensión \n- Enf.Cardiacas \n- Asma \n- Otras(Especificar)\n\n"))

info = ["Fecha de nacimiento", "Peso", "Altura", "IMC"]
boleta = ["Nombre", "Celular", "enfermedad detectada del paciente"]
df02 = pd.DataFrame(list(zip(boleta, data_asistencia)), columns=['Datos del Contacto', 'Resultado'])

print("\n---INGRESAR TIPO DE ASISTENCIA---\n(1) Emergencia\n(2) Cita Médica\n(3) Salir\n")

x = int(input("Ingresar Opción: "))

if (x == 1):
    print("\n--Contacto para Comunicarnos--\n")
    data_asistencia.append(input("Ingresar Nombre(s) y Apellidos: "))
    data_asistencia.append(int(input("Ingresar Celular: ")))
    data_asistencia.append(input(
        "¿Padece de alguna de estas Enfermedades?\nEscriba la que corresponde: \n- Diabetes \n- Hipertensión \n- Enf.Cardiacas \n- Asma \n- Otras(Especificar)\n\n"))
    df02 = pd.DataFrame(list(zip(boleta, data_asistencia)), columns=['Datos del Contacto', 'Resultado'])

    caso = 1

elif (x == 2):
    data_asistencia.append(input("Fecha de Nacimiento: "))
    data_asistencia.append(float(input("Ingresar Peso: ")))
    data_asistencia.append(float(input("Ingresar Altura: ")))
    imc = data_asistencia[1] / (data_asistencia[2] ** 2)
    data_asistencia.append(imc)

    df03 = pd.DataFrame(list(zip(info, data_asistencia)), columns=['REQUERIMIENTO', 'RECOPILADO'])

    print("\nIngrese Servicio - Especialidad:\n")
    opcionservi = int(input("\nIngrese Servicio - Especialidad:\n1) Cardiología\n2) Ecografía\n3) Neumología\n\n"))
    if (opcionservi == 1):
        data3 = {'Informacion': ["servicio", "Doctor", "Dias de atención", "Horario"],
                 'Disponibilidad': ["Cardiología", "Dr. Juan Perez", "martes-jueves", "3:00 - 5:00"]}
        df04 = pd.DataFrame(data3, columns=['Informacion', 'Disponibilidad'])

        caso = 2

    elif (opcionservi == 3):
        data3 = {'Informacion': ["servicio", "Doctor", "Dias de atención", "Horario"],
                 'Disponibilidad': ["Neumología", "Dra. Juana Ramaycuna", "lunes-jueves", "2:00 - 6:00"]}
        df04 = pd.DataFrame(data3, columns=['Informacion', 'Disponibilidad'])

        caso = 2

    else:
        print("Error")
elif (x == 3):
    print("break")
else:
    print("Error")


def casuistica(caso):
    for caso in [caso]:
        if (caso == 1):
            print("\n\n\n\n///////////////////////////////////////////////////////\n====== CITA PROGRAMADA ======")
            print("///////////////////////////////////////////////////////\n\n== BOLETA ==\n\nDATOS DEL PACIENTE:\n__________________________________________________________\n")
            print(df01)
            print("\n\nDATOS DE CONTACTO EN CASO DE NO PODERNOS CONTACTAR CON EL PACIENTE\n__________________________________________________________\n")
            print(df02)
            print("\n\n¡GRACIAS POR SU PREFERENCIA!\n////////////////////////////////////////////////////")
        elif (caso == 2):
            print("\n\n\n//////////////////////////////////////////////\n====== CITA PROGRAMADA ======")
            print("//////////////////////////////////////////////\n\n== BOLETA ==\n\nDATOS DEL PACIENTE:\n__________________________________________________________\n")
            print(df01)
            print("\n\nMAYOR INFORMACIÓN DEL PACIENTE\n__________________________________________________________\n")
            print(df03)
            print("\n\nINFORMACIÓN DEL SERVICIO ADQIRIDO\n__________________________________________________________\n")
            print(df04)
            print("\n\n¡GRACIAS POR SU PREFERENCIA!\n///////////////////////////////////////////////////////")


casuistica(caso)
1
# Out:
# ---BIENVENIDO A LA CLINICA PERUANO JAPONES---
#  -----------------------------------------
#
#  Datos del Paciente
# Ingresar Nombre(s) y Apellidos: 1
# Ingresar DNI: 1
# Ingresar Edad: 1
# lugar donde nacio 1
# Ingresar Domicilio: 1
# Ingresar Celular: 1
# ingrese tipo de sangre 1
#
# Gracias por llenar datos del paciente ..!!!
#
# --Contacto para Comunicarnos--
#
# Ingresar Nombre(s) y Apellidos: 1
# Ingresar Celular: 1
# ¿Padece de alguna de estas Enfermedades?
# Escriba la que corresponde:
# - Diabetes
# - Hipertensión
# - Enf.Cardiacas
# - Asma
# - Otras(Especificar)
#
# 1
#
# ---INGRESAR TIPO DE ASISTENCIA---
# (1) Emergencia
# (2) Cita Médica
# (3) Salir
#
# Ingresar Opción: 1
#
# --Contacto para Comunicarnos--
#
# Ingresar Nombre(s) y Apellidos: 1
# Ingresar Celular: 1
# ¿Padece de alguna de estas Enfermedades?
# Escriba la que corresponde:
# - Diabetes
# - Hipertensión
# - Enf.Cardiacas
# - Asma
# - Otras(Especificar)
#
# 1
#
#
#
#
# ...
